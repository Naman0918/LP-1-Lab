# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import AgglomerativeClustering
from sklearn.preprocessing import StandardScaler

# Load the dataset
df = pd.read_csv('/Users/namanlabhsetwar/Desktop/Sem 5 Practical/ML- Lab Assignments/LP-1 Dataset/K-Means & Hirarchical Clustering/50_Startups.csv')

# Display the first few rows of the dataframe
print(df.head())

# Check for missing values
print(df.isnull().sum())

# Select relevant columns for clustering
X = df[['PROFIT', 'RND']]

# Standardize the data
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Perform Agglomerative Clustering
aglo = AgglomerativeClustering(n_clusters=3)
labels = aglo.fit_predict(X_scaled)

# Plot the clusters
plt.scatter(X_scaled[:, 0], X_scaled[:, 1], c=labels, cmap='viridis')
plt.title('Hierarchical Clustering: PROFIT vs RND')
plt.xlabel('PROFIT (Standardized)')
plt.ylabel('RND (Standardized)')
plt.show()
# Out:
#          RND      ADMIN        MKT       STATE     PROFIT
# 0  165349.20  136897.80  471784.10    New York  192261.83
# 1  162597.70  151377.59  443898.53  California  191792.06
# 2  153441.51  101145.55  407934.54     Florida  191050.39
# 3  144372.41  118671.85  383199.62    New York  182901.99
# 4  142107.34   91391.77  366168.42     Florida  166187.94
# RND       0
# ADMIN     0
# MKT       0
# STATE     0
# PROFIT    0
# dtype: int64

# %%
df.head()
# Out:
#          RND      ADMIN        MKT       STATE     PROFIT
# 0  165349.20  136897.80  471784.10    New York  192261.83
# 1  162597.70  151377.59  443898.53  California  191792.06
# 2  153441.51  101145.55  407934.54     Florida  191050.39
# 3  144372.41  118671.85  383199.62    New York  182901.99
# 4  142107.34   91391.77  366168.42     Florida  166187.94

# %%
from scipy.cluster.hierarchy import linkage, dendrogram
link = linkage(X, method='ward')
dendrogram(link, p =3, truncate_mode='level')
# Out:
# {'icoord': [[15.0, 15.0, 25.0, 25.0],
#   [5.0, 5.0, 20.0, 20.0],
#   [35.0, 35.0, 45.0, 45.0],
#   [55.0, 55.0, 65.0, 65.0],
#   [40.0, 40.0, 60.0, 60.0],
#   [12.5, 12.5, 50.0, 50.0],
#   [75.0, 75.0, 85.0, 85.0],
#   [95.0, 95.0, 105.0, 105.0],
#   [80.0, 80.0, 100.0, 100.0],
#   [115.0, 115.0, 125.0, 125.0],
#   [135.0, 135.0, 145.0, 145.0],
#   [120.0, 120.0, 140.0, 140.0],
#   [90.0, 90.0, 130.0, 130.0],
#   [31.25, 31.25, 110.0, 110.0]],
#  'dcoord': [[0.0, 12039.626524751502, 12039.626524751502, 0.0],
#   [0.0, 34170.505951517596, 34170.505951517596, 12039.626524751502],
#   [0.0, 24283.283927967474, 24283.283927967474, 0.0],
#   [0.0, 40467.598476484214, 40467.598476484214, 0.0],
#   [24283.283927967474,
#    62336.81011676654,
#    62336.81011676654,
#    40467.598476484214],
#   [34170.505951517596,
#    129328.53431681053,
#    129328.53431681053,
#    62336.81011676654],
#   [0.0, 22472.616536136822, 22472.616536136822, 0.0],
# ...
